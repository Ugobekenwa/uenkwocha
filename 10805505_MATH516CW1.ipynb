# %% [markdown]
# # 10805505_MATH516 COURSEWORK: Machine learning with Python
#
# In this lab report MRI datasets in Python was loaded. Then a practical inspection and cleaning of the data. This report provided hands on practical instructions on how to filter, pre-process, analyse, and select significant feature that will be used in the machine learning model development. The lab will then provide practical instructions and examples on the development of robust machine learning models for the purposes of disease classification or diagnosis; data preparation, the creation of machine learning models in python, model training and testing, and performance evaluation.

# %% [markdown]
# # Aims and Objectives
#
# The aims of this Lab are to:
#
# 1. introduce how to load datasets, such as clinical datasets in Python, and to show on how the loaded data can be inspected and cleaned.
#
# 2. provide a practical introduction to using Jupyter notebook for data manipulation, such as pre-processing, exploratory analysis, feature analysis and selection.
#
# 3. provide practical hands-on experience on the creation, training, testing, validation, and performance evaluation of machine learning models.

# %% [markdown]
# **Instructions**
#
# - Work through each section in order
# - This tutorial is part of a series that support the taught material

# %% [markdown]
# ## Import libraries
# In order to load the dataset we will need to load required libraries or functions

# %%
# Import libraries that we need
import numpy as np  # library to support large multi-dimensional arrays and matrices and functions     
import pandas as pd    # for data manipulation and analysis
import seaborn as sns    # plotting library
import matplotlib.pyplot as plt # plotting library

# %%
'''
    1. Import required libraries
'''
import numpy as np  # library to support large multi-dimensional arrays and matrices and functions     
import pandas as pd    # for data manipulation and analysis
import seaborn as sns    # plotting library
import matplotlib.pyplot as plt # plotting library

# %%
## Load dataset

# %%
# Load dataset (we use the 'Data_training_and_val_set_CNvsAD.csv')
df=pd.read_csv('Data_training_and_val_set_CNvsAD.csv')

# %% [markdown]
# ### Inspect dataset

# %%
# Inspect: number of samples and features
df.shape
# Out:
# (220, 17)

# %%
df
# Out:
#       RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0    1063   937159  1401690     38855.4  3427.13  3262.01    1045.280
# 1     184   901429  1235930     10081.2  3410.35  3693.69     529.756
# 2      16   935565  1345440     21299.0  3621.49  3802.43     887.978
# 3     575   884775  1325760     69220.3  2802.91  3098.38    3215.570
# 4     403  1062950  1498230     32967.7  3416.55  4103.49    1648.410
# ..    ...      ...      ...         ...      ...      ...         ...
# 215   712   856859  1323290     64639.2  2889.79  2612.19    3275.190
# 216  1377  1097900  1716660     76240.9  2661.54  3167.81    2745.350
# 217  1254   973188  1561140     90250.4  2653.06  2605.33    3005.910
# 218  1337  1105000  1589110     41649.7  2321.26  2855.26    1902.090
# 219   850   958399  1387660     31165.3  2642.92  2612.68    2248.550
#
#      RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# ...

# %%
# Inspect: number of samples and number of samples
print(str("dataset has ") + str(df.shape[0])+str(' samples / instances & ')+str(df.shape[1])+ str(' features'))
# Out:
# dataset has 220 samples / instances & 17 features

# %%
# Inspect the dataset

# uncomment line below to see data
#df
# Out:
#   File "<ipython-input-2-8e418c11a7e1>", line 4
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
# Inspect: first 10 rows / samples

# uncomment line below to see data
#df.head(10)

# %%
df.head(10)
# Out:
#     RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0  1063   937159  1401690    38855.40  3427.13  3262.01    1045.280
# 1   184   901429  1235930    10081.20  3410.35  3693.69     529.756
# 2    16   935565  1345440    21299.00  3621.49  3802.43     887.978
# 3   575   884775  1325760    69220.30  2802.91  3098.38    3215.570
# 4   403  1062950  1498230    32967.70  3416.55  4103.49    1648.410
# 5    22   883799  1215670     7552.46  3116.90  3134.69     296.264
# 6   489   835754  1181440    20250.00  3653.31  3744.91     551.022
# 7  1249   912204  1324510    17322.60  3393.06  3625.90     714.723
# 8    74  1023260  1564110    89868.70  3098.29  2784.63    1708.540
# 9  1197   883461  1340390    34558.30  3234.71  3226.95    1352.980
#
#    RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 0    1263.010   2.44566   2.48342   2.47434   2.49197    2.27057    2.11083
# ...

# %%
# Inspect: Feature names -- column names 
df.columns
# Out:
# Index(['RID', 'BRAIN', 'EICV', 'VENTRICLES', 'LHIPPOC', 'RHIPPOC',
#        'LINFLATVEN', 'RINFLATVEN', 'LMIDTEMP', 'RMIDTEMP', 'LINFTEMP',
#        'RINFTEMP', 'LFUSIFORM', 'RFUSIFORM', 'LENTORHIN', 'RENTORHIN',
#        'DXCURREN'],
#       dtype='object')

# %% [markdown]
# **TASK**
#
#     1. read the dementia dataset (dementia.csv) from file
#     2. list the number of features

# %% [markdown]
# ### Clean dataset

# %% [markdown]
# **Comment**
# In many cases, clinical dataset may have missing values.
#
# Missingness can be dealt with in several ways e.g.
# - replacing missing values by interpolation of other values
# - deleting any feature that has one or more missing values
# - deleting features that have missing values above a set threshold
#
# The first task when dealing with missingness is to determine / count the number
# of missing values per feature
#
# Let us now count the missing values in the cancer dataset
#
# we use pandas isna() function to check if any there are missing values
# <br> we combine this with sum() function to count all missing values per column
#
# isna() - Documentation here:
#
# <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html>

# %%
'''
    Count the number of missing values 
    for each feature / column
'''
df.isna().sum()
# Out:
# RID           0
# BRAIN         0
# EICV          0
# VENTRICLES    0
# LHIPPOC       0
# RHIPPOC       0
# LINFLATVEN    0
# RINFLATVEN    0
# LMIDTEMP      0
# RMIDTEMP      0
# LINFTEMP      0
# RINFTEMP      0
# LFUSIFORM     0
# RFUSIFORM     0
# LENTORHIN     0
# RENTORHIN     0
# DXCURREN      0
# dtype: int64

# %% [markdown]
# **Note**
#
# There are no missing values in the cancer dataset
# For demonstration purposes, let us import a dataset that has missing values

# %% [markdown]
# ### Dropping features with missing values
# We can drop all rows having at least one null value
# - use the Pandas dropna() function
# - Documentation can be found here:</p>
# <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html?highlight=dropna>

# %% [markdown]
# # Data Manipulation
#
# In this section we will go through data:
# - Filtering
# - Pre-processing
# - Exploratory Analysis
# - Feature selection
# - Scaling

# %% [markdown]
# ## Filtering witth Pandas
# Filtering is a very common operation in data science and machine learning.
#
# Pandas library has many tools that allow
# - data to be selected from the main dataset according to labels, rows and columns
# - allows the extraction of data subsets based on columns and rows -- using boolean indexing
#
# In this subsection we will show how to extract:
#
# - single column from the dataset
# - multiple columns from the dataset
# - single row from the dataset
# - multiple rows from the dataset
# - combination of rows and columns from the dataset
# - data based on Boolean expressions

# %% [markdown]
# ### Single column extraction
# the **.** and **[]** operators can be used in pandas to select single columns
#
# to start we will list the features that describe the dataset

# %%
# List features
df.columns
# Out:
# Index(['RID', 'BRAIN', 'EICV', 'VENTRICLES', 'LHIPPOC', 'RHIPPOC',
#        'LINFLATVEN', 'RINFLATVEN', 'LMIDTEMP', 'RMIDTEMP', 'LINFTEMP',
#        'RINFTEMP', 'LFUSIFORM', 'RFUSIFORM', 'LENTORHIN', 'RENTORHIN',
#        'DXCURREN'],
#       dtype='object')

# %% [markdown]
# **Example**
#
# Extract the following sinle features
# - mean_radius
# - mean_compactness
#
# we will us the . and [] operators

# %%
# select 'mean_radius' using [] operator

# uncomment line below to see data
#df['mean_radius']

# %%
# Select 'BRAIN' using [] operator
df['BRAIN']
# Out:
# 0       937159
# 1       901429
# 2       935565
# 3       884775
# 4      1062950
#         ...
# 215     856859
# 216    1097900
# 217     973188
# 218    1105000
# 219     958399
# Name: BRAIN, Length: 220, dtype: int64

# %%
# select 'LHIPPOC' using [] operator
df['LHIPPOC']
# Out:
# 0      3427.13
# 1      3410.35
# 2      3621.49
# 3      2802.91
# 4      3416.55
#         ...
# 215    2889.79
# 216    2661.54
# 217    2653.06
# 218    2321.26
# 219    2642.92
# Name: LHIPPOC, Length: 220, dtype: float64

# %%
# select 'mean_radius' using . operator

# uncomment line below to see data
#df.mean_radius

# %%
# select 'mean_compactness' using [] operator

# uncomment line below to see data
#df['mean_compactness']

# %%
# select 'mean_compactness' using . operator

# uncomment line below to see data
#df.mean_compactness

# %%
# select 'RHIPPOC' using [] operator
df['RHIPPOC']
# Out:
# 0      3262.01
# 1      3693.69
# 2      3802.43
# 3      3098.38
# 4      4103.49
#         ...
# 215    2612.19
# 216    3167.81
# 217    2605.33
# 218    2855.26
# 219    2612.68
# Name: RHIPPOC, Length: 220, dtype: float64

# %% [markdown]
# ##  Multiple columns can be selected by passing **a list of column names**:
# <br>*df[list of column names]*
#
# Let us extract the multiple features
# - 'mean_radius', 'mean_compactness'
# - 'concave_points_error', 'symmetry_error', 'fractal_dimension_error'

# %% [markdown]
# **Example**
#
# extract 'mean_radius', 'mean_compactness'
#
# **NOTE: the double brackets [[ ]] **

# %%
# extract 'mean_radius', 'mean_compactness'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
#df[['mean_radius', 'mean_compactness']]

# %%
# extract 'BRAIN', 'RHIPPOC'
# NOTE: the double brackets [[ ]]


df[['BRAIN', 'RHIPPOC']]
print(table.txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-01c5c7e57c18> in <module>
#       4
#       5 df[['BRAIN', 'RHIPPOC']]
# ----> 6 print(table.txt)
#
# NameError: name 'table' is not defined

# %%
# extract 'BRAIN', 'LHIPPOC'
# NOTE: the double brackets [[ ]]


df[['BRAIN', 'LHIPPOC']]
# Out:
#        BRAIN  LHIPPOC
# 0     937159  3427.13
# 1     901429  3410.35
# 2     935565  3621.49
# 3     884775  2802.91
# 4    1062950  3416.55
# ..       ...      ...
# 215   856859  2889.79
# 216  1097900  2661.54
# 217   973188  2653.06
# 218  1105000  2321.26
# 219   958399  2642.92
#
# [220 rows x 2 columns]

# %%
# extract 'mean_radius', 'mean_compactness'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
#df[['concave_points_error', 'symmetry_error', 'fractal_dimension_error']]

# %%
 # extract 'EICV', 'VENTRICLES', 'LHIPPOC', 'RHIPPOC', 'LINFLATVEN', 'RINFLATVEN', 'LMIDTEMP'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
df[['EICV','VENTRICLES', 'LINFLATVEN', 'RINFLATVEN']]
# Out:
#         EICV  VENTRICLES  LINFLATVEN  RINFLATVEN
# 0    1401690     38855.4    1045.280    1263.010
# 1    1235930     10081.2     529.756     391.364
# 2    1345440     21299.0     887.978    1135.170
# 3    1325760     69220.3    3215.570    3370.800
# 4    1498230     32967.7    1648.410    1480.410
# ..       ...         ...         ...         ...
# 215  1323290     64639.2    3275.190    6056.760
# 216  1716660     76240.9    2745.350    4233.470
# 217  1561140     90250.4    3005.910    5159.180
# 218  1589110     41649.7    1902.090    1429.610
# 219  1387660     31165.3    2248.550    2621.690
#
# [220 rows x 4 columns]

# %%
# extract 'mean_radius', 'mean_compactness'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
#df[['concave_points_error', 'symmetry_error', 'fractal_dimension_error']]

# %%
# extract 'mean_radius', 'mean_compactness'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
#df[['mean_radius', 'mean_compactness', 'concave_points_error', 'symmetry_error', 'fractal_dimension_error']]

# %%
# extract 'LFUSIFORM', 'RFUSIFORM', 'LENTORHIN', 'RENTORHIN'
# NOTE: the double brackets [[ ]]

# uncomment line below to see data
df[['LFUSIFORM', 'RFUSIFORM', 'LENTORHIN', 'RENTORHIN']]
# Out:
#      LFUSIFORM  RFUSIFORM  LENTORHIN  RENTORHIN
# 0      2.27057    2.11083    2.99752    3.24032
# 1      2.42640    2.50153    3.40556    3.36431
# 2      1.99782    2.40015    3.19497    3.02149
# 3      2.09972    2.12354    2.43217    2.99445
# 4      2.38363    2.48169    3.71762    3.86305
# ..         ...        ...        ...        ...
# 215    2.35629    1.88668    2.24954    1.82813
# 216    1.95258    1.75652    2.37322    2.25815
# 217    2.10478    2.11616    2.36305    2.62898
# 218    2.38113    2.36953    2.75257    3.25038
# 219    2.22663    2.13674    2.63225    1.70942
#
# [220 rows x 4 columns]

# %% [markdown]
# ###  In pandas we can select (filter) according to the data type of features using
#
# *pandas.DataFrame.select_dtypes(include=None, exclude=None)*
#
# see documentation here:
# <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html>

# %% [markdown]
# **Example**
#
# Select numeric features

# %%
# Example -- select numeric features

# uncomment line below to see data
#df.select_dtypes(include='number')

# Note we only have numeric features

# %%
df.select_dtypes(include='number')
# Out:
#       RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0    1063   937159  1401690     38855.4  3427.13  3262.01    1045.280
# 1     184   901429  1235930     10081.2  3410.35  3693.69     529.756
# 2      16   935565  1345440     21299.0  3621.49  3802.43     887.978
# 3     575   884775  1325760     69220.3  2802.91  3098.38    3215.570
# 4     403  1062950  1498230     32967.7  3416.55  4103.49    1648.410
# ..    ...      ...      ...         ...      ...      ...         ...
# 215   712   856859  1323290     64639.2  2889.79  2612.19    3275.190
# 216  1377  1097900  1716660     76240.9  2661.54  3167.81    2745.350
# 217  1254   973188  1561140     90250.4  2653.06  2605.33    3005.910
# 218  1337  1105000  1589110     41649.7  2321.26  2855.26    1902.090
# 219   850   958399  1387660     31165.3  2642.92  2612.68    2248.550
#
#      RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# ...

# %% [markdown]
# **Let us use the penguins dataset that has mixed types**
#
# but let us first check what data types are availab

# %%
# check data types
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# **Example**
# Select select object

# %%
# Example -- select select object

# uncomment line below to see data
#penguins.select_dtypes(include='object')

# %%
penguins.select_dtypes(include='object')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 3    Adelie  Torgersen     NaN
# 4    Adelie  Torgersen  Female
# ..      ...        ...     ...
# 339  Gentoo     Biscoe     NaN
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [344 rows x 3 columns]

# %%
# Example -- include float64 features

# uncomment line below to see data
#penguins.select_dtypes(include='float64')

# %%
penguins.select_dtypes(include='float64')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %% [markdown]
# ###  We can also exclude features of a certain data type from the data

# %% [markdown]
# **Example**
#
# Exclude  object

# %%
# Example -- exclude  object

# uncomment line below to see data
#penguins.select_dtypes(exclude='object')

# %%
penguins.select_dtypes(exclude='object')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
# Example -- exclude float64 features

# uncomment line below to see data
#penguins.select_dtypes(exclude='float64')

# %%
penguins.select_dtypes(exclude='float64')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 3    Adelie  Torgersen     NaN
# 4    Adelie  Torgersen  Female
# ..      ...        ...     ...
# 339  Gentoo     Biscoe     NaN
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [344 rows x 3 columns]

# %% [markdown]
# ###  Extract single rows
# using **.loc[] indexer**
# <br>NB: Different from MATLAB
# <br> where one does not have to use .iloc </br>
#
# reference here: <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html?highlight=iloc>

# %%
# Example select row 0

# uncomment line below to see data
#df.iloc[[0]]

# %%
df.iloc[[0]]
# Out:
#     RID   BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0  1063  937159  1401690     38855.4  3427.13  3262.01     1045.28
#
#    RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 0     1263.01   2.44566   2.48342   2.47434   2.49197    2.27057    2.11083
#
#    LENTORHIN  RENTORHIN  DXCURREN
# 0    2.99752    3.24032         0

# %%
# Example select row 2 

# uncomment line below to see data
#df.iloc[[2]]

# %%
df.iloc[[2]]
# Out:
#    RID   BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  RINFLATVEN  \
# 2   16  935565  1345440     21299.0  3621.49  3802.43     887.978     1135.17
#
#    LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  LENTORHIN  \
# 2   2.45128   2.53828   2.40015   2.46122    1.99782    2.40015    3.19497
#
#    RENTORHIN  DXCURREN
# 2    3.02149         0

# %%
# Example select row 40

# uncomment line below to see data
#df.iloc[[40]]

# %% [markdown]
# ### Select multiple rows

# %%
# Example select row 10 and 20

# uncomment line below to see data
#df.iloc[[10, 20]]

# %%
df.iloc[[10, 20]]
# Out:
#     RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 10  516  1050350  1501100     26103.5  3573.24  3806.69     1207.11
# 20  610   893337  1438540     51954.1  2948.66  3116.64     1618.55
#
#     RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 10     1180.95    2.4656   2.60656   2.68490   2.58197    2.31397    2.43062
# 20     1767.76    2.4105   2.64381   2.52312   2.62348    2.32689    2.37887
#
#     LENTORHIN  RENTORHIN  DXCURREN
# 10    3.41886    3.57889         0
# 20    2.90044    3.17772         0

# %%
# Example select row 0 and 5

# uncomment line below to see data
#df.iloc[[0, 5]]

# %%
df.iloc[[0, 5]]
# Out:
#     RID   BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0  1063  937159  1401690    38855.40  3427.13  3262.01    1045.280
# 5    22  883799  1215670     7552.46  3116.90  3134.69     296.264
#
#    RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 0    1263.010   2.44566   2.48342   2.47434   2.49197    2.27057    2.11083
# 5     319.986   2.57935   2.58767   2.62718   2.72099    2.51178    2.39900
#
#    LENTORHIN  RENTORHIN  DXCURREN
# 0    2.99752    3.24032         0
# 5    2.84030    3.17907         0

# %% [markdown]
# #### DataFrame Slicing

# %%
# Example get the first 3 rows

# uncomment line below to see data
#df.iloc[:3]

# %%
df.iloc[:3]
# Out:
#     RID   BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0  1063  937159  1401690     38855.4  3427.13  3262.01    1045.280
# 1   184  901429  1235930     10081.2  3410.35  3693.69     529.756
# 2    16  935565  1345440     21299.0  3621.49  3802.43     887.978
#
#    RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 0    1263.010   2.44566   2.48342   2.47434   2.49197    2.27057    2.11083
# 1     391.364   2.52101   2.69526   2.81781   2.76115    2.42640    2.50153
# 2    1135.170   2.45128   2.53828   2.40015   2.46122    1.99782    2.40015
#
#    LENTORHIN  RENTORHIN  DXCURREN
# 0    2.99752    3.24032         0
# 1    3.40556    3.36431         0
# 2    3.19497    3.02149         0

# %%
# Example get rows 10 to 14 (15-1)

# uncomment line below to see data
#df.iloc[10:15]

# %%
df.iloc[10:15]
# Out:
#     RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 10  516  1050350  1501100     26103.5  3573.24  3806.69    1207.110
# 11  692   901700  1371920     43790.9  3614.53  3573.92    1001.940
# 12  685   992971  1454790     40222.0  3501.67  3371.10     998.997
# 13  741  1036570  1462780     31377.3  3281.57  2628.94     891.339
# 14  120  1121230  1567280     21265.3  3845.99  3915.61     851.945
#
#     RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 10    1180.950   2.46560   2.60656   2.68490   2.58197    2.31397    2.43062
# 11    1118.250   2.37751   2.47041   2.35168   2.61533    2.05026    2.32662
# 12    1467.140   2.51553   2.67670   2.75689   2.77987    2.38658    2.67080
# 13    1567.960   2.60006   2.41667   2.49347   2.47831    2.39820    2.33631
# 14     937.541   2.56921   2.54422   2.61002   2.72495    2.52310    2.47183
#
#     LENTORHIN  RENTORHIN  DXCURREN
# 10    3.41886    3.57889         0
# ...

# %% [markdown]
# ###  Extracting rows and columns (slicing)

# %%
# Example: slicing rows 0 and 2 columns 1 and 3

df.iloc[[0, 2], [1, 3]]
# Out:
#     BRAIN  VENTRICLES
# 0  937159     38855.4
# 2  935565     21299.0

# %%
# Example: slicing rows 5 to 9, columns 20 and 19

# uncomment line below to see data
#df.iloc[5:10, 20:30]

# %%
df.iloc[5:10, 20:30]
# Out:
# Empty DataFrame
# Columns: []
# Index: [5, 6, 7, 8, 9]

# %%
# selecting rows by position

# uncomment line below to see data
#df.iloc[[0, 3, 10, 12, 14]]

# %%
df.iloc[[0, 3, 10, 12, 14]]
# Out:
#      RID    BRAIN     EICV  VENTRICLES  LHIPPOC  RHIPPOC  LINFLATVEN  \
# 0   1063   937159  1401690     38855.4  3427.13  3262.01    1045.280
# 3    575   884775  1325760     69220.3  2802.91  3098.38    3215.570
# 10   516  1050350  1501100     26103.5  3573.24  3806.69    1207.110
# 12   685   992971  1454790     40222.0  3501.67  3371.10     998.997
# 14   120  1121230  1567280     21265.3  3845.99  3915.61     851.945
#
#     RINFLATVEN  LMIDTEMP  RMIDTEMP  LINFTEMP  RINFTEMP  LFUSIFORM  RFUSIFORM  \
# 0     1263.010   2.44566   2.48342   2.47434   2.49197    2.27057    2.11083
# 3     3370.800   2.59348   2.62409   2.50552   2.95271    2.09972    2.12354
# 10    1180.950   2.46560   2.60656   2.68490   2.58197    2.31397    2.43062
# 12    1467.140   2.51553   2.67670   2.75689   2.77987    2.38658    2.67080
# 14     937.541   2.56921   2.54422   2.61002   2.72495    2.52310    2.47183
#
#     LENTORHIN  RENTORHIN  DXCURREN
# 0     2.99752    3.24032         0
# ...

# %%
# selecting disjointed rows and columns
# Slect rows 1,9 columns 0, 10, 13
df.iloc[[1, 9], [0, 10, 13]]
# Out:
#     RID  LINFTEMP  RFUSIFORM
# 1   184   2.81781    2.50153
# 9  1197   2.50001    2.17892

# %%
df.iloc[[1, 9], [0, 10, 13]]
# Out:
#     RID  LINFTEMP  RFUSIFORM
# 1   184   2.81781    2.50153
# 9  1197   2.50001    2.17892

# %% [markdown]
# **Task**
# - Select any number of rows and columns of your chosing

# %% [markdown]
# ## Pre-processing
#
# - Creating training and test sets from the main dataset
# - Feature scaling

# %% [markdown]
# ### Data splitting

# %%
# Import data splitting library
from sklearn.model_selection import train_test_split

# split dataset into data and labels 
X,y=df.drop(columns=['DXCURREN']), df['DXCURREN']

# split data into train and test set 705 training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state= 1)

# %%
# confirm splitting
print(X.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (220, 16) (165, 16) (55, 16) (165,) (55,)

# %% [markdown]
# ### Feature scaling
#
# - Datasets may have features that in most cases are of different scales
# - some features may be very big while some may be small in value
# - big-valued features may dominate small-valued fetures when used to train a ML model
# - to avoid dominance, all features should be to the same range e.g. 0 - 1; -1 - 1; -3 - 3; etc.

# %% [markdown]
# **Scale training data**
#
# NB: pre-processing on training dataset

# %%
# Import preprocessing library
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# we only aply the feature scaling on the features other than dummy variables.
X_train_sc = sc.fit_transform(X_train)

# %% [markdown]
# **Confirm scaling**
#
# by printing the scaled dataset

# %%
# Confirm scaling of the train data

# uncomment line below to see data
#pd.DataFrame(X_train_sc, columns=[X.columns])

# %%
# Confirm scaling of the train data
pd.DataFrame(X_train_sc, columns=[X.columns])
# Out:
#           RID     BRAIN      EICV VENTRICLES   LHIPPOC   RHIPPOC LINFLATVEN  \
# 0    0.249658 -0.968922 -0.869089  -0.484249 -1.943178 -1.053535   0.104842
# 1    0.280660  0.706997  0.168628  -0.470980 -0.202528  0.112008  -0.466600
# 2   -1.267058  0.725394  1.297340   2.451965  0.693507  0.796639   1.760018
# 3   -1.379142  1.358025  0.674313  -1.008590  1.043933  0.921516  -0.914066
# 4   -1.441146 -0.351431  0.029353   0.437989 -0.744310 -1.249150  -0.017368
# ..        ...       ...       ...        ...       ...       ...        ...
# 149  0.979398 -1.565529 -1.502858  -0.856430 -1.122399 -1.487387  -0.430915
# 150  1.086713  0.614824  0.867494   1.336711 -0.308524  0.007280   0.393292
# 151 -0.651786 -0.161904  0.396659   0.656037 -0.072544 -0.449890   2.769850
# 152  0.366512 -1.040360 -0.986686  -0.875438 -1.909913 -1.542384  -0.206309
# 153 -1.355294  2.376618  1.657612  -0.932204  1.714107  1.530820  -0.929180
#
# ...

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Stats
#
# Pandas - describe() function can be used to generate descriptive statistics of the dataset features
# <br>Reference documentation here: <https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html>

# %%
# Generate descriptive statistics
df.describe()
# Out:
#                RID         BRAIN          EICV     VENTRICLES      LHIPPOC  \
# count   220.000000  2.200000e+02  2.200000e+02     220.000000   220.000000
# mean    697.381818  9.732298e+05  1.455089e+06   46819.713000  3147.849182
# std     410.637915  1.085988e+05  1.530882e+05   25260.106084   628.351722
# min       7.000000  6.345910e+05  1.059560e+06    7552.460000  1723.310000
# 25%     373.500000  8.992745e+05  1.343640e+06   28324.100000  2673.720000
# 50%     691.000000  9.744355e+05  1.454475e+06   42132.200000  3182.570000
# 75%    1067.000000  1.044310e+06  1.565938e+06   59839.475000  3554.165000
# max    1430.000000  1.303590e+06  1.949090e+06  152927.000000  5514.940000
#
#            RHIPPOC   LINFLATVEN   RINFLATVEN    LMIDTEMP    RMIDTEMP  \
# count   220.000000   220.000000   220.000000  220.000000  220.000000
# mean   3315.357955  1742.216973  1748.802286    2.391393    2.428251
# std     645.180948  1031.871538  1101.229703    0.278645    0.271520
# ...

# %%
# Transpose for ease of presentation
stats_dataset= df.describe().T
stats_dataset.head(10)
stats_dataset.to_csv("Temporary_Data.txt", sep = ",")

# %% [markdown]
# ### The descriptive statistics are not separate for each class
# To see statistical differences,
# - extract dataset for Normal subjects
# - extract dataset for AD subjects
# - generate statistics for each group
# - compare statistics

# %%
'''
    get stats for Normal
'''
negative=df[df['DXCURREN']==0].describe().T
negative.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eb7f8f2550cd> in <module>
#       2     get stats for Normal
#       3 '''
# ----> 4 negative=df[df['DXCURREN']==0].describe().T
#       5 negative.head(5)
#
# NameError: name 'df' is not defined

# %%
'''
    get stats for Positive
'''
positive=df[df['DXCURREN']==1].describe().T
positive.head(5)
# Out:
#             count          mean            std         min           25%  \
# RID         110.0  7.763818e+02     430.459451        7.00  3.940000e+02
# BRAIN       110.0  9.501246e+05  111523.069171   693786.00  8.639480e+05
# EICV        110.0  1.451390e+06  166893.400071  1118990.00  1.320102e+06
# VENTRICLES  110.0  5.552915e+04   27362.518583    11559.90  3.544505e+04
# LHIPPOC     110.0  2.762603e+03     549.719272     1723.31  2.352622e+03
#
#                     50%           75%         max
# RID             799.500  1.150000e+03     1430.00
# BRAIN        943792.500  1.018635e+06  1303590.00
# EICV        1447620.000  1.578445e+06  1949090.00
# VENTRICLES    48609.600  6.990448e+04   152927.00
# LHIPPOC        2676.645  3.103387e+03     4853.35

# %% [markdown]
# #### Compare statistics
# - create a dataframe comparing means of negative and AD
# - calculate log2 fold changes between normal and AD

# %%
# create dataframe
feat_means=pd.DataFrame({'negative':negative[:-1]['mean'], 'positive':positive[:-1]['mean']})

# calculate fold changes and add to dataframe
fc=(feat_means.positive - feat_means.negative)/feat_means.negative
feat_means['fc']=fc

# calculate Log2 of fold change and add to data frame
log2_fc=np.log2(np.abs(fc))
feat_means['log2_fc']=log2_fc
feat_means=feat_means.reset_index().rename(columns={'DXCURREN':'feature'})

# sort dataframe according to fold change
feat_means['abs']=abs(feat_means['fc'])

# Sort by fold absolute change
feat_means=feat_means.sort_values(by=['abs'],ascending=False).drop(columns=['abs'])
feat_means.head(10)
# Out:
#          index      negative      positive        fc   log2_fc
# 6   LINFLATVEN   1234.750545   2249.683400  0.821974 -0.282835
# 7   RINFLATVEN   1244.294327   2253.310245  0.810914 -0.302379
# 3   VENTRICLES  38110.280545  55529.145455  0.457065 -1.129530
# 0          RID    618.381818    776.381818  0.255506 -1.968573
# 4      LHIPPOC   3533.095727   2762.602636 -0.218079 -2.197079
# 14   LENTORHIN      3.186655      2.499836 -0.215530 -2.214040
# 15   RENTORHIN      3.298458      2.589077 -0.215064 -2.217159
# 5      RHIPPOC   3678.580818   2952.135091 -0.197480 -2.340222
# 8     LMIDTEMP      2.564385      2.218401 -0.134919 -2.889837
# 9     RMIDTEMP      2.598034      2.258468 -0.130701 -2.935656

# %%
'''
    plot fold changes (elevation or reduction)
    in vals between negative and positive subjects
'''
plt.figure(figsize=(18,6))
plt.bar(feat_means['index'],feat_means['fc'], color ='blue',width = 0.4)
plt.xticks(feat_means['index'], rotation ='vertical')
plt.xlabel('index')
plt.ylabel('Log2 Fold change')
plt.tight_layout()

# save plot
plt.savefig('neg_post_subjects.jpeg')

# %% [markdown]
# ###  Boxplots
#
# We may plot box plots
# - to show distributions of the numeric values
# - these provide a visual comparison between groups in the data (e.g. negative and positive patients
# - they provide information at a glance

# %% [markdown]
# **Let us start by listing the features**

# %%
features=df.drop(columns=['DXCURREN']).columns
features
# Out:
# Index(['RID', 'BRAIN', 'EICV', 'VENTRICLES', 'LHIPPOC', 'RHIPPOC',
#        'LINFLATVEN', 'RINFLATVEN', 'LMIDTEMP', 'RMIDTEMP', 'LINFTEMP',
#        'RINFTEMP', 'LFUSIFORM', 'RFUSIFORM', 'LENTORHIN', 'RENTORHIN'],
#       dtype='object')

# %% [markdown]
# **Box plot of single feature**

# %%
# ApoE
sns.boxplot(x = df['DXCURREN'],y = df[features[0]])
#ax = sns.swarmplot(x="index", y="worst_concave_points", data=dataset, color='#7d0013')
# Out:
# <AxesSubplot:xlabel='DXCURREN', ylabel='RID'>

# %%
# ApoE
sns.boxplot(x = df['DXCURREN'],y = df['BRAIN'])
#ax = sns.swarmplot(x="index", y="worst_concave_points", data=dataset, color='#7d0013')
# Out:
# <AxesSubplot:xlabel='DXCURREN', ylabel='BRAIN'>

# %% [markdown]
# **Task**
# - Select any two features and boxplot their values
# - Do you think they may be useful biomarkers?

# %% [markdown]
# **Boxplots for first 4 features**

# %%
#set seaborn plotting aesthetics as default
sns.set()

#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(16,6))

#create boxplot in each subplot
sns.boxplot(x = df['DXCURREN'],y = df[features[0]], ax=axes[0,0])
sns.boxplot(x = df['DXCURREN'],y = df[features[1]], ax=axes[0,1])
sns.boxplot(x = df['DXCURREN'],y = df[features[2]], ax=axes[1,0])
sns.boxplot(x = df['DXCURREN'],y = df[features[3]], ax=axes[1,1])
plt.savefig('subplot_regions.png')

# %% [markdown]
# ### Augmentation

# %% [markdown]
# **Data augmentation to solve imbalance**
#
# - There are many libraries and techniques for data augmentation
# - we will use **Synthetic Minority Oversampling Technique (SMOTE)**

# %%
# Count number of samples per class

# Load the dataset from file
dataset=pd.read_csv('Data_training_and_val_set_CNvsAD.csv')

target_count = dataset['DXCURREN'].value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])

# Plot result
dataset['DXCURREN'].value_counts().plot(kind='bar', title='Count (DXCURREN)');
plt.savefig('sample_per_class.png')
# Out:
# Class 0: 110
# Class 1: 110

# %% [markdown]
# **Task**
#
# - Discuss the problem that an imbalanced dataset my have on training a Machine learning classifier

# %%
'''
    Augment dataset to get balanced dataset
'''
# Import SMOTE library
from imblearn.over_sampling import SMOTE

# Create a smote object
smt=SMOTE() # create a SMOTE object

# seperate the data and labels
X = dataset.drop(columns=['DXCURREN']) # just the data
y = dataset['DXCURREN'] # just the class values
# y = dataset_under['DXCURREN'] # this syntax also works

'''
    train or fit the SMOTE object 
    use it to oversample the minority class
    generate 
    
    X_sm -- data after oversampling
    y_sm -- labels of oversampled data
'''
X_sm, y_sm=smt.fit_resample(X,y) # oversample

# Concatenate data and labels to get augmented dataset dataset
dataset_sm = pd.concat([X_sm, y_sm], axis=1)

# counts of imbalanced dataset
print(y_sm.value_counts())

# Plot result
dataset_sm['DXCURREN'].value_counts().plot(kind='bar', title='Count (DXCURREN)');
plt.savefig('balanced_data.png')
# Out:
# 0    110
# 1    110
# Name: DXCURREN, dtype: int64

# %% [markdown]
# # Classification

# %% [markdown]
# ## Baseline Machine Learning Classifier Development and Testing

# %%
# 1. Import required libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Load dataset
df=pd.read_csv('Data_training_and_val_set_CNvsAD.csv')

# 2. split data into training and test sets
X, y = df.drop(columns=['DXCURREN']), df['DXCURREN'] #

# split data into train & test sets: 70% training & 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

print("Accuracy on test data: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy on test data: 0.91

# %% [markdown]
# **Re-examine base classifier performance**

# %%
# 1. Import required libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Load ADNI Plasma dataset
#df1=pd.read_csv('./dataset/adni_plasma_v1.csv').sample(frac=1.0)
df=pd.read_csv('Data_training_and_val_set_CNvsAD.csv')

# 2. split data into training and test sets
X, y = df.drop(columns=['DXCURREN']), df['DXCURREN'] 

# split data into train & test sets: 70% training & 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 

# Create a RandomForest classiefer
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training data sets
clf.fit(X_train, y_train)

# Print the performance of the classifier
print("Accuracy on test data: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy on test data: 0.91

# %% [markdown]
# **Task**
# - load the dementia dataset
# - use the data to train and test a RandomForestClassifier
# - Print and comment on performance

# %% [markdown]
# **How to calculate Performance evaluation using Confusion matrix**
#
# Plot the Confusion Matrix to visualise the performance of the classifier

# %%
# 1. Import required libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# load data
df=pd.read_csv('Data_training_and_val_set_CNvsAD.csv')

# 2. split data into training and test sets
X, y = df.drop(columns=['DXCURREN']), df['DXCURREN'] 

# split data into train & test sets: 70% training & 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 

# Create a RandomForest classiefer
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training data sets
clf.fit(X_train, y_train)

# predict outcomes of the test dataset using the trained classifier
y_pred=clf.predict(X_test)

# Get the confusion metrix from predicted labels and actual labels
cf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(cf_matrix, annot=True, fmt='', cmap='Blues')
plt.savefig('split_data.png')

# %% [markdown]
# **TASK**
#
# Calculate the following performance metrics
# 1. Accuracy
# 2. Sensitivity
# 3. Specificity
# 3. Precision
# 5. Recall

# %% [markdown]
# **These metrics can be computed from sklearn metrics library**

# %% [markdown]
# **We can now calculate performance once we have**
# - y_pred -- prediction of the test set
# - y_test -- the actual labels for the test set

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from imblearn.metrics import specificity_score

Accuracy = accuracy_score(y_test, y_pred)
Specificity = specificity_score(y_test, y_pred)
Recall=recall_score(y_test, y_pred)
f1_score = f1_score(y_test, y_pred)

# Compute the Matthews correlation coefficient (MCC)
mcc=matthews_corrcoef(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)

auc_score
# Out:
# 0.9108455882352942

# %% [markdown]
# **Create and train a basic model on data**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import spearmanr
from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform

from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

X, y = dataset.drop(columns=['DXCURREN']), dataset['DXCURREN']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
print("Accuracy on test data: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy on test data: 0.91

# %% [markdown]
# **Quickly check feature Importance**

# %%
result = permutation_importance(clf, X_train, y_train, n_repeats=10, random_state=42)
perm_sorted_idx = result.importances_mean.argsort()

tree_importance_sorted_idx = np.argsort(clf.feature_importances_)
tree_indices = np.arange(0, len(clf.feature_importances_)) + 0.5

fig, (ax1) = plt.subplots(1, 1, figsize=(12, 8))
ax1.barh(tree_indices, clf.feature_importances_[tree_importance_sorted_idx], height=0.7)
ax1.set_yticks(tree_indices)
ax1.set_yticklabels(dataset.columns[tree_importance_sorted_idx])
ax1.set_ylim((0, len(clf.feature_importances_)))

fig.tight_layout()
plt.show()
plt.savefig('feature_importance.png')

# %% [markdown]
# **Comment**
# - results show that features may cintribute differently to model
# - some features are more significant and other features less important
# - it therefore make sense to rank features and select those that are significant
# - this leads to **feature ranking** and **feature selection**
# - this may also be referred to marker or **biomarker** selection

# %% [markdown]
# ## Feature Ranking
# There are many methods for feature ranking
# - each method may result in slightly different ranking of features
# - in general, the features are ranked using many techniques or metrics
# - a final ranking is then obtained by averaging the ranking from several methods
# - the ranked features are then used for selecting the optimal number of features

# %% [markdown]
# **Embedded Feature ranking**

# %%
from sklearn.ensemble import RandomForestClassifier, SupportVectorClassifier, AdaBoostClassifier, GradientBoostingClassifier
import matplotlib.pyplot as plt

# Define estimator
estimator = RandomForestClassifier(n_estimators = 100, max_depth = 7, min_samples_leaf = 2, min_samples_split = 2, random_state=220)

#estimator.fit(X_selected, y_all_train)
estimator.fit(X_train, y_train)

# get feature importances
embedded_feature_ranking = pd.DataFrame({'feature':X_train.columns,'importance':estimator.feature_importances_})

# create a dataFrame of feature importance
#imp=pd.DataFrame({'feature':X_selected.columns,'importance':estimator.feature_importances_}).sort_values(by='importance',ascending=False)
imp=pd.DataFrame({'feature':X_train.columns,'importance':estimator.feature_importances_}).sort_values(by='importance',ascending=False)


# get significant features
significant_features = imp[imp.importance >= 0.0]

imp.plot.bar(x='feature', y='importance', rot=0,figsize=(22,8), color='blue')
plt.xticks(rotation='vertical',fontsize=11)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('Normalised importance',fontsize=14)
plt.legend(fontsize=14)
plt.title('Features Ranked by Normalised Importance',fontsize=16)
plt.tight_layout()
plt.savefig('ranked_by_normalised_importance.jpeg')

# %% [markdown]
# **Task**
# - print the ranked features

# %% [markdown]
# **Correlation-based feature ranking**

# %%
correlation_mat
# Out:
#                  RID     BRAIN      EICV  VENTRICLES   LHIPPOC   RHIPPOC  \
# RID         1.000000 -0.069415 -0.024789    0.041432 -0.175389 -0.184805
# BRAIN      -0.069415  1.000000  0.912216    0.171445  0.549739  0.584769
# EICV       -0.024789  0.912216  1.000000    0.458553  0.374653  0.408710
# VENTRICLES  0.041432  0.171445  0.458553    1.000000 -0.247190 -0.238254
# LHIPPOC    -0.175389  0.549739  0.374653   -0.247190  1.000000  0.874785
# RHIPPOC    -0.184805  0.584769  0.408710   -0.238254  0.874785  1.000000
# LINFLATVEN  0.059162  0.050195  0.327650    0.830020 -0.442392 -0.367566
# RINFLATVEN -0.000693 -0.020929  0.263568    0.796454 -0.422129 -0.460156
# LMIDTEMP   -0.122019  0.308598  0.054694   -0.422180  0.528607  0.460678
# RMIDTEMP   -0.172001  0.308464  0.064329   -0.367395  0.521768  0.524862
# LINFTEMP   -0.065915  0.307999  0.066326   -0.395688  0.542053  0.460240
# RINFTEMP   -0.053664  0.287228  0.042950   -0.374164  0.469562  0.484583
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_mat = df.corr('spearman')

# ranking
correlation_feature_rank=pd.DataFrame({'feature':correlation_mat.DXCURREN, 'cor':correlation_mat.DXCURREN}).reset_index().drop(columns=['DXCURREN'])
correlation_feature_rank['abs']=abs(correlation_feature_rank.cor)

ranked=pd.DataFrame({'feature':correlation_mat.index, 'cor':correlation_mat['DXCURREN']}).reset_index().drop(columns=['DXCURREN'])
ranked['abs']=abs(ranked.cor)
ranked=ranked.sort_values(by=['abs'],ascending=False).drop(columns=['abs']).iloc[1:]

ranked.plot.bar(x='feature', y='cor', rot=0,figsize=(22,8), color='blue')
plt.xticks(rotation='vertical',fontsize=11)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('Spearman Ranked Correlation',fontsize=14)
plt.legend(fontsize=14)
plt.title('Features Ranked by correlation',fontsize=16)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-dcb3df48fdaf> in <module>
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 correlation_mat = df.corr('spearman')
#       5
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# **Print ranked features**

# %%
correlation_feature_rank[:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-70cd476b3421> in <module>
# ----> 1 correlation_feature_rank[:-1]
#
# NameError: name 'correlation_feature_rank' is not defined

# %% [markdown]
# **Plot heatmap of feature correlations**

# %%
#corr = df.corr()
corr = df.drop(columns=['DXCURREN']).corr()
fig, ax = plt.subplots(figsize=(20,12))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.savefig('heatmap_correlations.jpeg')

# %% [markdown]
# **P-values feature ranking**
# - Pvalues may be used to determine the signifcance of features
# - It may also be used to rank features

# %%
from scipy import stats

# seperate the two sets of data
a=dataset[dataset['DXCURREN']==0].drop(columns=['DXCURREN'])
b=dataset[dataset['DXCURREN']==1].drop(columns=['DXCURREN'])

pvals_feature_ranking=(pd.DataFrame(stats.ttest_ind(a,b)).T).drop(columns=[0]).rename(columns={1: "p_value"})
pvals_feature_ranking.insert(0, "feature", dataset.drop(columns=['DXCURREN']).columns)

rank_pvals=(pd.DataFrame(stats.ttest_ind(a,b)).T).drop(columns=[0]).rename(columns={1: "p_value"})
rank_pvals.insert(0, "feature", dataset.drop(columns=['DXCURREN']).columns)
rank_pvals=rank_pvals.sort_values(by=['p_value'])

rank_pvals.plot.bar(x='feature', y='p_value', rot=0,figsize=(22,8), color='blue')
plt.xticks(rotation='vertical',fontsize=11)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('p_value',fontsize=14)
plt.legend(fontsize=14)
plt.title('Features Ranked by p_value',fontsize=16)
plt.axhline(y = 0.05, color = 'r', linestyle = '--')
plt.tight_layout()

plt.savefig('ranked_by_Pvalve.jpeg')

# %% [markdown]
# **print p_values**

# %%
pvals_feature_ranking
# Out:
#        feature       p_value
# 0          RID  4.095462e-03
# 1        BRAIN  1.464905e-03
# 2         EICV  7.209300e-01
# 3   VENTRICLES  1.444776e-07
# 4      LHIPPOC  3.110688e-24
# 5      RHIPPOC  6.790456e-20
# 6   LINFLATVEN  7.197735e-15
# 7   RINFLATVEN  7.144266e-13
# 8     LMIDTEMP  5.668557e-25
# 9     RMIDTEMP  2.069136e-25
# 10    LINFTEMP  1.167292e-26
# 11    RINFTEMP  2.104613e-19
# 12   LFUSIFORM  3.829996e-20
# 13   RFUSIFORM  9.731913e-18
# 14   LENTORHIN  3.026538e-27
# 15   RENTORHIN  9.028144e-25

# %% [markdown]
# **Task**
#
#     1. Look up pValue
#     2. What is it and how is it used for hypothesis testing
#     3. How can it be used for feature ranking or selection

# %% [markdown]
# ###  Recursive Feature Elimination (RFE)
# Feature ranking with recursive feature elimination
#
# Documentation here: <https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html>
#
# **How does it work?**
#
# **NB:** Use with an estimator that provides feature importance metric e.g. RandomForest

# %%
'''
      RFE feature ranking
      NB: 1 -- highest rank
'''
from sklearn.feature_selection import RFE

data, target=dataset.drop(columns=['DXCURREN']), dataset['DXCURREN']
estimator=RandomForestClassifier()
rfe = RFE(estimator, n_features_to_select=1).fit(data, target)
rf_ranking=rfe.ranking_
features= data.columns


rfe_feature_ranking = pd.DataFrame({'feature': features, 'rank':rf_ranking})
#
ranked_ref=pd.DataFrame({'feature': features, 'rank':rf_ranking})#.sort_values(by=['rank'])
ranked_ref.plot.bar(x='feature', y='rank', rot=0,figsize=(22,8), color='blue')
plt.xticks(rotation='vertical',fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('Rank',fontsize=14)
plt.legend(fontsize=14)
plt.title('Features Ranked by importance',fontsize=16)
plt.tight_layout()
plt.savefig("ranked_by_importance.png")

# %%
rfe_feature_ranking
# Out:
#        feature  rank
# 0          RID    15
# 1        BRAIN    11
# 2         EICV    16
# 3   VENTRICLES    13
# 4      LHIPPOC     3
# 5      RHIPPOC     8
# 6   LINFLATVEN     9
# 7   RINFLATVEN    10
# 8     LMIDTEMP     5
# 9     RMIDTEMP     6
# 10    LINFTEMP     1
# 11    RINFTEMP    12
# 12   LFUSIFORM     7
# 13   RFUSIFORM    14
# 14   LENTORHIN     2
# 15   RENTORHIN     4

# %% [markdown]
# ##    ~ End ~

# %% [markdown]
# # Thank you
